# %%
import pybaseball

# %%
# %pip install pybaseball

# %%
from pybaseball import playerid_lookup

# %%
ohtani_id = playerid_lookup('ohtani', 'shohei')['key_mlbam'][0]
# Out:
# Gathering player lookup table. This may take a moment.

# %%
ohtani_id
# Out:
# 660271

# %% [markdown]
# # Ohtani Batting

# %%
from pybaseball import statcast_batter

# %%
import datetime 

yesterday = datetime.date.today() - datetime.timedelta(days=1)

# %%
ohtani_batting_stats = statcast_batter('2023-01-01','2023-12-31',ohtani_id)
# Out:
# Gathering Player Data

# %%
ohtani_batting_stats.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         ST  2024-03-26           79.8          -1.74           5.87
# 1         FS  2024-03-26           86.5          -1.58           6.10
# 2         FF  2024-03-26           93.6          -1.76           6.03
# 3         ST  2024-03-26           81.4          -1.88           5.85
# 4         FS  2024-03-26           84.9          -1.63           6.06
#
#       player_name  batter  pitcher     events      description  ...  \
# 0  Ohtani, Shohei  660271   681217  strikeout  swinging_strike  ...
# 1  Ohtani, Shohei  660271   681217        NaN             ball  ...
# 2  Ohtani, Shohei  660271   681217        NaN    called_strike  ...
# 3  Ohtani, Shohei  660271   681217        NaN             ball  ...
# 4  Ohtani, Shohei  660271   681217        NaN  swinging_strike  ...
#
#    post_home_score  post_bat_score  post_fld_score  if_fielding_alignment  \
# ...

# %%
from utils.zone_plot import zone_plot   


zone_dist = ohtani_batting_stats["zone"].value_counts().sort_index()

# %%
zone_dist
# Out:
# 1.0      92
# 2.0     106
# 3.0      78
# 4.0     162
# 5.0     157
# 6.0     111
# 7.0     131
# 8.0     133
# 9.0      87
# 11.0    282
# 12.0    181
# 13.0    475
# 14.0    333
# Name: zone, dtype: int64

# %%
zone_dist[:9].to_numpy()
# Out:
# array([ 92, 106,  78, 162, 157, 111, 131, 133,  87])

# %%
# zone_dist[:9].to_numpy().reshape(3,3)
zone_plot(zone_dist[:9].to_numpy().reshape(3,3), zone_dist[11:].to_numpy())

# %% [markdown]
# ## Actual data obtained from statcast plotting

# %%
from IPython.display import Image
display(Image(filename='352a65f7-9867-4e64-86a9-9f7df8536548.jpg'))

# %% [markdown]
# # Ohtani Pitching

# %%
from pybaseball import statcast_pitcher

ohtani_pitching_stats = statcast_pitcher('2023-01-01','2023-12-31',ohtani_id)

ohtani_pitching_stats.head()
# Out:
# Gathering Player Data
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2023-08-23           94.2          -1.98           5.78
# 1         ST  2023-08-23           76.1          -2.01           5.74
# 2         ST  2023-08-23           77.2          -2.05           5.60
# 3         FS  2023-08-23           90.1          -1.94           5.69
# 4         FS  2023-08-23           90.0          -1.83           5.76
#
#       player_name  batter  pitcher events      description  ...  \
# 0  Ohtani, Shohei  687952   660271    NaN             foul  ...
# 1  Ohtani, Shohei  687952   660271    NaN  swinging_strike  ...
# 2  Ohtani, Shohei  687952   660271    NaN  swinging_strike  ...
# 3  Ohtani, Shohei  687952   660271    NaN             ball  ...
# 4  Ohtani, Shohei  687952   660271    NaN     blocked_ball  ...
#
#    post_home_score  post_bat_score  post_fld_score  if_fielding_alignment  \
# ...

# %%
ohtani_pitching_stats.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'player_name', 'batter', 'pitcher', 'events',
#        'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
# ...

# %%
ohtani_pitching_stats['pitch_type'].value_counts()
# Out:
# ST    737
# FF    690
# FC    329
# FS    131
# SI    126
# CU     76
# SL      5
# Name: pitch_type, dtype: int64

# %%
ohtani_pitching_stats['pitch_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: >
